# %%
# from gurobipy import *
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import pickle
import time
import PFSMG as pfsmg
import functions as func

# %%
# SEED_arr = [1122334455, 666, 8899, 558866, 559966, 99998866, 99888866, 9966668, 99677808, 7542229,  \
#             11234455, 6600451, 8852099, 110036, 277066, 277066, 900186, 9820816, 908253, 1089532]
# param_arr = np.arange(1.2, 8.2, 0.35)

SEED_arr = [1122334455, 7666, 88799, 5589866, 5590966, 9998866, 9058866, 9966668, 99677808, 7542229,  \
            11234455, 6600451, 8852099, 110036, 277066, 277066, 900186, 9820816, 908253, 1089532]
param_arr = np.arange(1.2, 8.2, 0.35)

# %%
font = {'color':  'black',
        'weight': 'normal',
        'size': 18,
        }

# %%
data_idx = 0
prob = func.Fairness_LogRe('data/testData_seed%s_param%s.txt'%(SEED_arr[data_idx], param_arr[data_idx]), 'test_gender_modmod_seed%s_param%s'%(SEED_arr[data_idx], param_arr[data_idx]), 3)
run = pfsmg.Main_SMG(prob)
f1_arrays7, f2_arrays7, point_arrays7, total_time = run.main_SMG()

# fig7, ax7 = plt.subplots(figsize=(12,8))
# ax7.set_xlabel('f_1(x)')
# ax7.set_ylabel('f_2(x)')
# _ = ax7.plot(f1_arrays7, f2_arrays7,'k.')
# figure_path = "Test_fig_2/PFSMG/v3/Pareto_front_Name%s_Data%s_NumDatas%s_PfPts%s_Iters%s_Starpts%s_#ptPerIter%s.png"\
#           %(prob.name, prob.data_name, prob.num_data, run.max_len_pareto_front, run.num_iter, run.num_starting_pts, run.point_per_iteration)
# plt.title('Output of Pareto-front stochastic multi-gradient for data %s'%prob.data_name, fontdict=font)
# plt.savefig(figure_path)
# plt.show()
# print(len(f1_arrays7))
# Out:
# split 3
# idx [1 2 4]
# #Training data size:  2000
# sum of sensitive 1016.0
# time:  0.0102519989014
# #Pts:  2  #Iter:  2
# time:  0.00579905509949
# #Pts:  4  #Iter:  4
# time:  0.0268869400024
# #Pts:  12  #Iter:  6
# time:  0.0239658355713
# #Pts:  18  #Iter:  8
# time:  0.0363121032715
# #Pts:  20  #Iter:  10
# time:  0.0948948860168
# #Pts:  37  #Iter:  12
# time:  0.0732438564301
# #Pts:  45  #Iter:  14
# time:  0.0912389755249
# #Pts:  48  #Iter:  16
# time:  0.102955102921
# #Pts:  61  #Iter:  18
# time:  0.122258901596
# #Pts:  71  #Iter:  20
# time:  0.144530057907
# #Pts:  84  #Iter:  22
# time:  0.0938568115234
# #Pts:  92  #Iter:  24
# time:  0.185496091843
# #Pts:  102  #Iter:  26
# time:  0.208118915558
# #Pts:  104  #Iter:  28
# time:  0.113186836243
# #Pts:  121  #Iter:  30
# time:  0.244616985321
# #Pts:  139  #Iter:  32
# time:  0.281517028809
# #Pts:  152  #Iter:  34
# time:  0.133903980255
# #Pts:  161  #Iter:  36
# time:  0.323855161667
# ...

# %%
## pick a number of points from Pareto front and compute accuracy, TPR, FPR, D.I., etc. 
M = min(1500, len(f1_arrays7))
disparate_impact, percentage, pvalue, total_accuracy, training_accuracy, training_FPR, training_FNR, \
training_loss, training_obj1, training_obj2 \
= prob.compute_accuracy(f1_arrays7, f2_arrays7, point_arrays7, M)

# %%
fig8 = plt.figure(figsize=(12, 12), dpi= 80, facecolor='w', edgecolor='k')
ax1 = plt.subplot(3, 2, 1)
ax1.xaxis.set_tick_params(labelsize=13)
ax1.yaxis.set_tick_params(labelsize=13)
ax1.plot(training_loss, training_obj2, 'k.', lw=2)
ax1.set_xlabel('$f_1(x)$', fontsize = 13)
ax1.set_ylabel('$f_2(x)$', fontsize = 13)
# ax1.title('Pareto front')

ax2 = plt.subplot(3, 2, 2)
ax2.xaxis.set_tick_params(labelsize=13)
ax2.yaxis.set_tick_params(labelsize=13)
ax2.plot(training_obj2, percentage[:, 0],'b.', lw=2, label = 'Group1')
ax2.plot(training_obj2, percentage[:, 1],'r.', lw=2, label = 'Group2')
ax2.set_xlabel('$f_2(x)$', fontsize = 13)
ax2.set_ylabel('%Positive outcomes', fontsize = 13)
ax2.legend()






ax2.xaxis.set_tick_params(labelsize=13)
ax2.yaxis.set_tick_params(labelsize=13)
ax2.plot(pvalue, total_accuracy,'k.', lw=2)
ax2.set_xlabel('p-rule%', fontsize = 13)
ax2.set_ylabel('Accuracy', fontsize = 13)
# plt.title('Loss versus D.P. covarance')

ax3= plt.subplot(3, 2, 3)
ax3.xaxis.set_tick_params(labelsize=13)
ax3.yaxis.set_tick_params(labelsize=13)
ax3.plot(training_obj2, total_accuracy, 'k.', lw=2)
ax3.set_xlabel('f2(x)', fontsize = 13)
ax3.set_ylabel('Accuracy', fontsize = 13)
# plt.title('Demographically parity versus D.P. covarance')

ax4 = plt.subplot(3, 2, 4)


ax5 = plt.subplot(3, 2, 5)
ax5.xaxis.set_tick_params(labelsize=13)
ax5.yaxis.set_tick_params(labelsize=13)
ax5.plot(training_obj2, training_accuracy[:, 0], 'b.', lw=2, label = 'Group1')
ax5.plot(training_obj2, training_accuracy[:, 1], 'r.', lw=2, label = 'Group2')
ax5.set_xlabel('f2(x)', fontsize = 13)
ax5.set_ylabel('Accuracy', fontsize = 13)
ax5.legend()

ax6 = plt.subplot(3, 2, 6)
ax6.xaxis.set_tick_params(labelsize=13)
ax6.yaxis.set_tick_params(labelsize=13)
ax6.plot(disparate_impact, total_accuracy, 'k.', lw=2) #np.sqrt(training_obj2)
ax6.set_xlabel('CV Score', fontsize = 13)
ax6.set_ylabel('Accuracy', fontsize = 13)
# plt.title('Prediction accuracy versus D.P. covarance')

plt.tight_layout()
plt.show()
